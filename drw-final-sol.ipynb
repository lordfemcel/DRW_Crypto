# %%
import sys
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from scipy.stats import pearsonr
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
def feature_engineering(df):
    df = df.copy()
    df['order_flow_imbalance'] = (df['buy_qty'] - df['sell_qty']) / (df['buy_qty'] + df['sell_qty'] + 1e-8)
    df['liquidity_imbalance'] = (df['bid_qty'] - df['ask_qty']) / (df['bid_qty'] + df['ask_qty'] + 1e-8)
    df['bid_ask_spread'] = df['ask_qty'] - df['bid_qty']
    df['log_volume'] = np.log1p(df['volume'])
    
    df = df.replace([np.inf, -np.inf], np.nan)
    return df

# %%
train_df = pd.read_parquet("/kaggle/input/drw-crypto-market-prediction/train.parquet")
train_df.head(10)
# Out:
#                      bid_qty  ask_qty  buy_qty  sell_qty   volume        X1  \
# 2023-03-01 00:00:00   15.283    8.425  176.405    44.984  221.389  0.181844
# 2023-03-01 00:01:00   38.590    2.336  525.846   321.950  847.796  0.489497
# 2023-03-01 00:02:00    0.442   60.250  159.227   136.369  295.596  0.260121
# 2023-03-01 00:03:00    4.865   21.016  335.742   124.963  460.705  0.099976
# 2023-03-01 00:04:00   27.158    3.451   98.411    44.407  142.818  0.270893
# 2023-03-01 00:05:00   29.454    5.540  309.371    97.460  406.831 -0.558479
# 2023-03-01 00:06:00    3.478   29.514  100.608   233.525  334.133 -0.452937
# 2023-03-01 00:07:00   16.591    3.230   46.034   218.806  264.840  0.464475
# 2023-03-01 00:08:00    5.560   30.919   40.259    82.518  122.777  1.000941
# 2023-03-01 00:09:00   12.697   14.827  125.650    90.750  216.400  1.093672
#
#                            X2        X3        X4        X5  ...      X772  \
# 2023-03-01 00:00:00 -0.637860  0.006652  0.136870  0.116698  ...  0.333753
# 2023-03-01 00:01:00 -0.075619  0.431594  0.522400  0.475255  ...  0.333657
# 2023-03-01 00:02:00 -0.444684  0.100695  0.224729  0.203282  ...  0.333667
# 2023-03-01 00:03:00 -0.666728 -0.123858  0.019197  0.014459  ...  0.333174
# 2023-03-01 00:04:00 -0.325973  0.116336  0.234311  0.214073  ...  0.333171
# 2023-03-01 00:05:00 -1.655676 -1.033540 -0.814882 -0.756889  ...  0.332504
# 2023-03-01 00:06:00 -1.332166 -0.854345 -0.668494 -0.627297  ...  0.332695
# 2023-03-01 00:07:00  0.292593  0.441009  0.498789  0.449966  ...  0.333397
# 2023-03-01 00:08:00  1.145275  1.168142  1.166786  1.073158  ...  0.333931
# 2023-03-01 00:09:00  1.193154  1.258610  1.264540  1.172654  ...  0.333782
#
#                          X773      X774      X775      X776      X777  \
# 2023-03-01 00:00:00 -0.009992 -0.695595 -0.444077 -0.191238 -0.184251
# 2023-03-01 00:01:00 -0.010040 -0.696226 -0.452866 -0.200082 -0.188929
# 2023-03-01 00:02:00 -0.010037 -0.696832 -0.461383 -0.208786 -0.193571
# 2023-03-01 00:03:00 -0.010279 -0.697391 -0.469628 -0.217350 -0.198175
# 2023-03-01 00:04:00 -0.010283 -0.697940 -0.477622 -0.225780 -0.202745
# 2023-03-01 00:05:00 -0.010610 -0.698384 -0.485338 -0.234063 -0.207272
# 2023-03-01 00:06:00 -0.010519 -0.698833 -0.492821 -0.242217 -0.211766
# 2023-03-01 00:07:00 -0.010178 -0.699211 -0.500053 -0.250233 -0.216220
# 2023-03-01 00:08:00 -0.009919 -0.699591 -0.507064 -0.258124 -0.220640
# 2023-03-01 00:09:00 -0.009994 -0.699884 -0.513830 -0.265876 -0.225019
#
#                          X778      X779      X780     label
# 2023-03-01 00:00:00 -0.471897 -0.625428 -0.553991  0.562539
# 2023-03-01 00:01:00 -0.472842 -0.625832 -0.554426  0.533686
# 2023-03-01 00:02:00 -0.473785 -0.626236 -0.554860  0.546505
# 2023-03-01 00:03:00 -0.474726 -0.626639 -0.555294  0.357703
# 2023-03-01 00:04:00 -0.475666 -0.627043 -0.555728  0.362452
# 2023-03-01 00:05:00 -0.476601 -0.627445 -0.556162  0.100448
# 2023-03-01 00:06:00 -0.477535 -0.627847 -0.556595  0.178679
# 2023-03-01 00:07:00 -0.478466 -0.628248 -0.557028  0.463684
# 2023-03-01 00:08:00 -0.479395 -0.628649 -0.557461  0.686066
# 2023-03-01 00:09:00 -0.480320 -0.629049 -0.557893  0.637539
#
# [10 rows x 786 columns]

# %%
train_df.shape
# Out:
# (525886, 786)

# %%
train_df.isnull().sum()
# Out:
# bid_qty     0
# ask_qty     0
# buy_qty     0
# sell_qty    0
# volume      0
#            ..
# X777        0
# X778        0
# X779        0
# X780        0
# label       0
# Length: 786, dtype: int64

# %%
test_df = pd.read_parquet("/kaggle/input/drw-crypto-market-prediction/test.parquet")

# %%
test_df.shape
# Out:
# (538150, 786)

# %%
import optuna
import xgboost as xgb
from sklearn.model_selection import train_test_split

from scipy.stats import pearsonr

base_feature = ["bid_qty", "ask_qty", "buy_qty", "sell_qty", "volume"]

top_100_feature = ["X683", "X140", "X758", "X425", "X752", "X344", "X292", "X646",
                   "X287", "X134", "X385", "X647", "X682", "X279", "X345", "X466",
                   "X381", "X778", "X283", "X739", "X427", "X272", "X684", "X301",
                   "X198", "X465", "X608", "X738", "X384", "X137", "X386", "X581",
                   "X734", "X180", "X589", "X421", "X610", "X780", "X387", "X772",
                   "X654", "X428", "X96", "X779", "X426", "X98", "X591", "X650",
                   "X613", "X566", "X605", "X181", "X750", "X174", "X288", "X607",
                   "X579", "X176", "X508", "X178", "X419", "X219", "X343", "X89",
                   "X678", "X588", "X40", "X293", "X411", "X757", "X337", "X285",
                   "X295", "X341", "X443", "X179", "X575", "X751", "X92", "X562",
                   "X769", "X776", "X501", "X298", "X375", "X95", "X590", "X611",
                   "X94", "X270", "X424", "X86", "X587", "X434", "X638", "X170",
                   "X297", "X136", "X97", "X572"]


top_30_feature = top_100_feature[:30]

FEATURES = [*base_feature, *top_30_feature]

LABEL_COLUMN = "label"

#X=train_df[FEATURES]

#X_test = test_df[FEATURES]

X =  feature_engineering(train_df[FEATURES])
X_test =  feature_engineering(test_df[FEATURES])
y=train_df[LABEL_COLUMN]

# %%
from sklearn.model_selection import TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=3)
splits = list(tscv.split(X))
train_idx, valid_idx = splits[-1]
X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

# %%
X_train.shape
# Out:
# (394415, 39)

# %%
X_valid.shape
# Out:
# (131471, 39)

# %%
y_train.shape
# Out:
# (394415,)

# %%
y_valid.shape
# Out:
# (131471,)

# %%
# Hyperparameter tuning
def objective(trial):
    

    params = {
        "tree_method": "gpu_hist",
        "device": "cuda",
        "verbosity": 0,
        "random_state": 42,
        "n_jobs": -1,
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 20),
        "max_leaves": trial.suggest_int("max_leaves", 8, 64),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 30),
        "subsample": trial.suggest_float("subsample", 0.3, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.3, 1.0),
        "colsample_bynode": trial.suggest_float("colsample_bynode", 0.3, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 50.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0, 80.0),
        "n_estimators": 1667
    }

    scores = []
    
    for train_idx, valid_idx in tscv.split(X):
        
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        model = xgb.XGBRegressor(early_stopping_rounds=50, **params)
        
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], verbose=False)
        
        preds = model.predict(X_valid)
        r, _ = pearsonr(y_valid, preds)
        scores.append(r)

    return np.mean(scores)
    


# Create and run Optuna study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

#  results
print("Best Pearson correlation:", study.best_value)
print("Best Parameters:", study.best_params)
# Out:
# [I 2025-07-25 16:27:40,610] A new study created in memory with name: no-name-78039086-ffac-45b1-b0ee-e6f9ec1a261d
# [I 2025-07-25 16:27:44,922] Trial 0 finished with value: 0.07071738634390724 and parameters: {'learning_rate': 0.031191328016175378, 'max_depth': 20, 'max_leaves': 21, 'min_child_weight': 28, 'subsample': 0.7023333460249905, 'colsample_bytree': 0.8110917139233953, 'colsample_bylevel': 0.9014535352460094, 'colsample_bynode': 0.4079119169579721, 'gamma': 3.146102448471719, 'reg_alpha': 7.290715600785997, 'reg_lambda': 43.83540744344116}. Best is trial 0 with value: 0.07071738634390724.
# [I 2025-07-25 16:27:48,731] Trial 1 finished with value: 0.08036510828978448 and parameters: {'learning_rate': 0.033685055779316034, 'max_depth': 10, 'max_leaves': 8, 'min_child_weight': 30, 'subsample': 0.6198263124834795, 'colsample_bytree': 0.708074168870628, 'colsample_bylevel': 0.7615156634579913, 'colsample_bynode': 0.8765049148226713, 'gamma': 4.013010871098742, 'reg_alpha': 43.766569652277184, 'reg_lambda': 10.759420965170925}. Best is trial 1 with value: 0.08036510828978448.
# [I 2025-07-25 16:27:52,933] Trial 2 finished with value: 0.05648039761355635 and parameters: {'learning_rate': 0.07086978580294336, 'max_depth': 11, 'max_leaves': 38, 'min_child_weight': 21, 'subsample': 0.4784666626099118, 'colsample_bytree': 0.9098181622043727, 'colsample_bylevel': 0.531589773540573, 'colsample_bynode': 0.33615462337424973, 'gamma': 1.6083918708886817, 'reg_alpha': 48.86719926959695, 'reg_lambda': 9.7628858561679}. Best is trial 1 with value: 0.08036510828978448.
# [I 2025-07-25 16:27:57,088] Trial 3 finished with value: 0.011628172646003973 and parameters: {'learning_rate': 0.2940870992325617, 'max_depth': 9, 'max_leaves': 51, 'min_child_weight': 1, 'subsample': 0.425122471235133, 'colsample_bytree': 0.4807677937867708, 'colsample_bylevel': 0.8331516389749536, 'colsample_bynode': 0.7599791598655382, 'gamma': 1.6562513793840383, 'reg_alpha': 4.078793779047035, 'reg_lambda': 27.946012798740103}. Best is trial 1 with value: 0.08036510828978448.
# [I 2025-07-25 16:28:01,239] Trial 4 finished with value: 0.05880677787300186 and parameters: {'learning_rate': 0.2795382184563449, 'max_depth': 11, 'max_leaves': 36, 'min_child_weight': 18, 'subsample': 0.41221899198049927, 'colsample_bytree': 0.7679166488538418, 'colsample_bylevel': 0.9698377947194778, 'colsample_bynode': 0.48556304459217925, 'gamma': 3.6527518731757525, 'reg_alpha': 20.1112071444357, 'reg_lambda': 59.87701314900325}. Best is trial 1 with value: 0.08036510828978448.
# [I 2025-07-25 16:28:06,218] Trial 5 finished with value: 0.08221718289827955 and parameters: {'learning_rate': 0.01664940030217463, 'max_depth': 19, 'max_leaves': 19, 'min_child_weight': 8, 'subsample': 0.9765212336364022, 'colsample_bytree': 0.6072579248195632, 'colsample_bylevel': 0.9279673455408175, 'colsample_bynode': 0.48704721229087866, 'gamma': 2.693935415708652, 'reg_alpha': 14.877498083020802, 'reg_lambda': 37.041668878520184}. Best is trial 5 with value: 0.08221718289827955.
# [I 2025-07-25 16:28:10,069] Trial 6 finished with value: 0.08978686142735236 and parameters: {'learning_rate': 0.06218967692928269, 'max_depth': 3, 'max_leaves': 17, 'min_child_weight': 4, 'subsample': 0.6677865870803235, 'colsample_bytree': 0.9027477926404184, 'colsample_bylevel': 0.6566038222889884, 'colsample_bynode': 0.6497912560518884, 'gamma': 3.6099778644836804, 'reg_alpha': 18.7548262033362, 'reg_lambda': 2.4263114649570383}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:14,156] Trial 7 finished with value: 0.06392114746938986 and parameters: {'learning_rate': 0.04879243570151119, 'max_depth': 12, 'max_leaves': 28, 'min_child_weight': 8, 'subsample': 0.7098029584369335, 'colsample_bytree': 0.5821897969397879, 'colsample_bylevel': 0.82885205974584, 'colsample_bynode': 0.39768897715278095, 'gamma': 2.4899888099891716, 'reg_alpha': 11.74816867567024, 'reg_lambda': 68.95919304034307}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:18,029] Trial 8 finished with value: 0.07550524740535806 and parameters: {'learning_rate': 0.11041648458702227, 'max_depth': 18, 'max_leaves': 13, 'min_child_weight': 22, 'subsample': 0.4004414306812796, 'colsample_bytree': 0.7858003930423167, 'colsample_bylevel': 0.41972137430947276, 'colsample_bynode': 0.7095924286386552, 'gamma': 2.1985313592054356, 'reg_alpha': 49.20220482844926, 'reg_lambda': 79.06374344663007}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:22,495] Trial 9 finished with value: 0.08686816992494766 and parameters: {'learning_rate': 0.018553519648308873, 'max_depth': 17, 'max_leaves': 14, 'min_child_weight': 2, 'subsample': 0.4873340952890362, 'colsample_bytree': 0.5302302270219609, 'colsample_bylevel': 0.745846678303496, 'colsample_bynode': 0.5143030950079331, 'gamma': 0.03945350355279098, 'reg_alpha': 22.168804297302824, 'reg_lambda': 15.706348623932493}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:26,295] Trial 10 finished with value: 0.07423974850125407 and parameters: {'learning_rate': 0.12315272997861873, 'max_depth': 3, 'max_leaves': 60, 'min_child_weight': 10, 'subsample': 0.8741945155767229, 'colsample_bytree': 0.9946625797314641, 'colsample_bylevel': 0.3005778639539966, 'colsample_bynode': 0.9434203563652859, 'gamma': 4.8955651423033455, 'reg_alpha': 33.79110343834895, 'reg_lambda': 0.7037913016841131}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:31,021] Trial 11 finished with value: 0.079305822908796 and parameters: {'learning_rate': 0.011822529238844517, 'max_depth': 3, 'max_leaves': 27, 'min_child_weight': 1, 'subsample': 0.5666328921135231, 'colsample_bytree': 0.41047641488700126, 'colsample_bylevel': 0.6406586798846806, 'colsample_bynode': 0.5917775617682242, 'gamma': 0.1871575568501159, 'reg_alpha': 26.997963300049484, 'reg_lambda': 20.10961753612592}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:35,763] Trial 12 finished with value: 0.08855716865856621 and parameters: {'learning_rate': 0.02104352469979447, 'max_depth': 16, 'max_leaves': 15, 'min_child_weight': 5, 'subsample': 0.7896206170301958, 'colsample_bytree': 0.5777260861006098, 'colsample_bylevel': 0.6536811666777886, 'colsample_bynode': 0.5996921640279025, 'gamma': 0.10154341945350209, 'reg_alpha': 27.707706488588236, 'reg_lambda': 1.735162244643214}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:39,764] Trial 13 finished with value: 0.07450883356241335 and parameters: {'learning_rate': 0.027588906729899096, 'max_depth': 15, 'max_leaves': 8, 'min_child_weight': 12, 'subsample': 0.8144877414979897, 'colsample_bytree': 0.6379430362130711, 'colsample_bylevel': 0.5926231464872257, 'colsample_bynode': 0.6256948554464532, 'gamma': 0.9114646984876781, 'reg_alpha': 32.82429629905986, 'reg_lambda': 3.4704602986662203}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:43,894] Trial 14 finished with value: 0.07949797585898699 and parameters: {'learning_rate': 0.05798423132043089, 'max_depth': 7, 'max_leaves': 35, 'min_child_weight': 5, 'subsample': 0.7927264411384446, 'colsample_bytree': 0.9202875972771639, 'colsample_bylevel': 0.5082871198082267, 'colsample_bynode': 0.8056950255621426, 'gamma': 4.46972696249616, 'reg_alpha': 30.61305898731991, 'reg_lambda': 24.67383998043318}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:47,918] Trial 15 finished with value: 0.05979316442532678 and parameters: {'learning_rate': 0.09877334052090758, 'max_depth': 15, 'max_leaves': 24, 'min_child_weight': 13, 'subsample': 0.9575618383109781, 'colsample_bytree': 0.6920660638960472, 'colsample_bylevel': 0.7093219848425508, 'colsample_bynode': 0.6814332521544475, 'gamma': 3.4126148908927245, 'reg_alpha': 39.12764950319995, 'reg_lambda': 47.37922250666292}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:52,287] Trial 16 finished with value: 0.08184487340679518 and parameters: {'learning_rate': 0.044111454091709766, 'max_depth': 6, 'max_leaves': 45, 'min_child_weight': 6, 'subsample': 0.3021624934334846, 'colsample_bytree': 0.8462270439808043, 'colsample_bylevel': 0.6223950056716258, 'colsample_bynode': 0.5921189783160795, 'gamma': 0.7253069843386005, 'reg_alpha': 18.360499213741708, 'reg_lambda': 30.777663826212756}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:28:56,628] Trial 17 finished with value: 0.07337678284564578 and parameters: {'learning_rate': 0.010212796889254574, 'max_depth': 14, 'max_leaves': 16, 'min_child_weight': 16, 'subsample': 0.7419194607584277, 'colsample_bytree': 0.6979730043326008, 'colsample_bylevel': 0.4644414954295998, 'colsample_bynode': 0.7995545703601579, 'gamma': 4.077152892263758, 'reg_alpha': 0.41094557582896485, 'reg_lambda': 7.22669334299402}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:29:00,829] Trial 18 finished with value: 0.0688395863079407 and parameters: {'learning_rate': 0.02010808938508325, 'max_depth': 6, 'max_leaves': 30, 'min_child_weight': 5, 'subsample': 0.6013865288983068, 'colsample_bytree': 0.49326912492666075, 'colsample_bylevel': 0.6947720388354369, 'colsample_bynode': 0.5725291874655725, 'gamma': 1.6905670941892708, 'reg_alpha': 26.865111456696546, 'reg_lambda': 0.001890209094489892}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:29:05,073] Trial 19 finished with value: 0.02496260786108417 and parameters: {'learning_rate': 0.19554354725380368, 'max_depth': 13, 'max_leaves': 44, 'min_child_weight': 11, 'subsample': 0.8763824727692381, 'colsample_bytree': 0.9727023334679871, 'colsample_bylevel': 0.5589406629219663, 'colsample_bynode': 0.9969425139130242, 'gamma': 3.0092384499384215, 'reg_alpha': 13.327629885420112, 'reg_lambda': 17.54799641903917}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:29:09,475] Trial 20 finished with value: 0.07844978776785162 and parameters: {'learning_rate': 0.08117060558897186, 'max_depth': 16, 'max_leaves': 21, 'min_child_weight': 3, 'subsample': 0.6692787042846282, 'colsample_bytree': 0.8865678797990089, 'colsample_bylevel': 0.4129806217914672, 'colsample_bynode': 0.6656601374830633, 'gamma': 0.9112612727500002, 'reg_alpha': 39.598562954306374, 'reg_lambda': 50.405108422178834}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:29:13,853] Trial 21 finished with value: 0.07818224573661807 and parameters: {'learning_rate': 0.01817625865708644, 'max_depth': 17, 'max_leaves': 13, 'min_child_weight': 3, 'subsample': 0.5202597826105653, 'colsample_bytree': 0.5333295383117865, 'colsample_bylevel': 0.7488530035575363, 'colsample_bynode': 0.5198485667756033, 'gamma': 0.009297022392152555, 'reg_alpha': 20.929537321957667, 'reg_lambda': 14.49525161187622}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:29:17,993] Trial 22 finished with value: 0.08174415028308217 and parameters: {'learning_rate': 0.025888703517309326, 'max_depth': 17, 'max_leaves': 16, 'min_child_weight': 8, 'subsample': 0.5410937467378487, 'colsample_bytree': 0.5556184475943079, 'colsample_bylevel': 0.7939651868779892, 'colsample_bynode': 0.5241332687509102, 'gamma': 0.5540214147751155, 'reg_alpha': 23.893689644661237, 'reg_lambda': 13.20705455912476}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:29:22,674] Trial 23 finished with value: 0.08015701423503892 and parameters: {'learning_rate': 0.01418502467650406, 'max_depth': 20, 'max_leaves': 11, 'min_child_weight': 3, 'subsample': 0.7658097520936146, 'colsample_bytree': 0.413167721882422, 'colsample_bylevel': 0.6854781237956686, 'colsample_bynode': 0.7311485013421878, 'gamma': 1.173255481665191, 'reg_alpha': 23.38437607802023, 'reg_lambda': 21.942931567025525}. Best is trial 6 with value: 0.08978686142735236.
# [I 2025-07-25 16:29:27,071] Trial 24 finished with value: 0.09410417169771472 and parameters: {'learning_rate': 0.021446712637026064, 'max_depth': 8, 'max_leaves': 18, 'min_child_weight': 6, 'subsample': 0.6570611609562844, 'colsample_bytree': 0.6301521969871375, 'colsample_bylevel': 0.6560386960194589, 'colsample_bynode': 0.4370481817776824, 'gamma': 0.3965373333604827, 'reg_alpha': 17.04093729035139, 'reg_lambda': 6.525177359447243}. Best is trial 24 with value: 0.09410417169771472.
# [I 2025-07-25 16:29:31,081] Trial 25 finished with value: 0.07123532212128963 and parameters: {'learning_rate': 0.04017115102198271, 'max_depth': 8, 'max_leaves': 24, 'min_child_weight': 6, 'subsample': 0.6580147617349568, 'colsample_bytree': 0.6502690573020052, 'colsample_bylevel': 0.590217956213825, 'colsample_bynode': 0.41282152516228643, 'gamma': 0.4604128596123799, 'reg_alpha': 16.896650840093333, 'reg_lambda': 7.415441050448423}. Best is trial 24 with value: 0.09410417169771472.
# [I 2025-07-25 16:29:35,252] Trial 26 finished with value: 0.08039817076694201 and parameters: {'learning_rate': 0.022871972832629317, 'max_depth': 5, 'max_leaves': 31, 'min_child_weight': 14, 'subsample': 0.8092245403671723, 'colsample_bytree': 0.6326040194602696, 'colsample_bylevel': 0.6253227825119148, 'colsample_bynode': 0.34001662651577974, 'gamma': 1.3206538630272835, 'reg_alpha': 7.77626446028089, 'reg_lambda': 34.07221441116167}. Best is trial 24 with value: 0.09410417169771472.
# [I 2025-07-25 16:29:39,612] Trial 27 finished with value: 0.0964185050225329 and parameters: {'learning_rate': 0.05886679990832893, 'max_depth': 4, 'max_leaves': 19, 'min_child_weight': 9, 'subsample': 0.8585717810134676, 'colsample_bytree': 0.7398661178797925, 'colsample_bylevel': 0.7092082557557988, 'colsample_bynode': 0.4366631934747518, 'gamma': 2.2804995412667832, 'reg_alpha': 12.37976566079646, 'reg_lambda': 5.7432294751271025}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:29:43,389] Trial 28 finished with value: 0.04290213258757906 and parameters: {'learning_rate': 0.060220812170100786, 'max_depth': 4, 'max_leaves': 19, 'min_child_weight': 9, 'subsample': 0.8720044505743939, 'colsample_bytree': 0.7567144262718256, 'colsample_bylevel': 0.8499517628269085, 'colsample_bynode': 0.45950100327334636, 'gamma': 2.2502169353559798, 'reg_alpha': 10.745717708808673, 'reg_lambda': 6.596012114368444}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:29:47,252] Trial 29 finished with value: 0.04421026067001745 and parameters: {'learning_rate': 0.15710930697817393, 'max_depth': 5, 'max_leaves': 24, 'min_child_weight': 15, 'subsample': 0.695630647510376, 'colsample_bytree': 0.8367051726978995, 'colsample_bylevel': 0.8846563621542722, 'colsample_bynode': 0.4154448369880803, 'gamma': 3.036704510779845, 'reg_alpha': 8.326932039294498, 'reg_lambda': 24.1751331998642}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:29:51,802] Trial 30 finished with value: 0.07807490875080454 and parameters: {'learning_rate': 0.03481862617687328, 'max_depth': 8, 'max_leaves': 64, 'min_child_weight': 25, 'subsample': 0.9144517213536512, 'colsample_bytree': 0.7166839062862187, 'colsample_bylevel': 0.78533873078063, 'colsample_bynode': 0.31635805222308966, 'gamma': 3.5115552415210325, 'reg_alpha': 15.537356433360571, 'reg_lambda': 12.707996633490676}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:29:55,729] Trial 31 finished with value: 0.06564397851423683 and parameters: {'learning_rate': 0.07676541880356662, 'max_depth': 4, 'max_leaves': 20, 'min_child_weight': 6, 'subsample': 0.7255451427045588, 'colsample_bytree': 0.672271745315777, 'colsample_bylevel': 0.6698429540436612, 'colsample_bynode': 0.5674981238919039, 'gamma': 0.3112602518154368, 'reg_alpha': 29.457536628334992, 'reg_lambda': 3.4889096685386214}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:29:59,838] Trial 32 finished with value: 0.08616174345625793 and parameters: {'learning_rate': 0.03334487043327808, 'max_depth': 9, 'max_leaves': 9, 'min_child_weight': 5, 'subsample': 0.6177508589279747, 'colsample_bytree': 0.7298368036395572, 'colsample_bylevel': 0.696894981065187, 'colsample_bynode': 0.6328491365061548, 'gamma': 1.9644548265459594, 'reg_alpha': 18.055232218155286, 'reg_lambda': 4.987099029471737}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:30:03,724] Trial 33 finished with value: 0.06433722198640837 and parameters: {'learning_rate': 0.053705337322869695, 'max_depth': 3, 'max_leaves': 17, 'min_child_weight': 10, 'subsample': 0.8248362356196124, 'colsample_bytree': 0.5826921970968475, 'colsample_bylevel': 0.72650528857358, 'colsample_bynode': 0.37275895848219026, 'gamma': 4.029627097607986, 'reg_alpha': 5.072320847641848, 'reg_lambda': 9.338662033504217}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:30:07,735] Trial 34 finished with value: 0.06659915403509159 and parameters: {'learning_rate': 0.0884435985150978, 'max_depth': 10, 'max_leaves': 23, 'min_child_weight': 7, 'subsample': 0.759345823590853, 'colsample_bytree': 0.945963405327905, 'colsample_bylevel': 0.5557665598514532, 'colsample_bynode': 0.4437271810305758, 'gamma': 1.36491765145262, 'reg_alpha': 11.742882173231695, 'reg_lambda': 0.470175406277769}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:30:12,208] Trial 35 finished with value: 0.08680941382202666 and parameters: {'learning_rate': 0.04126699146089809, 'max_depth': 6, 'max_leaves': 12, 'min_child_weight': 4, 'subsample': 0.9310329626328957, 'colsample_bytree': 0.8234767879219533, 'colsample_bylevel': 0.6588396804214, 'colsample_bynode': 0.5314964725429571, 'gamma': 2.6080139077153173, 'reg_alpha': 25.97508961686481, 'reg_lambda': 11.17300617189169}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:30:17,099] Trial 36 finished with value: 0.0814215217520099 and parameters: {'learning_rate': 0.014393596325826097, 'max_depth': 5, 'max_leaves': 17, 'min_child_weight': 1, 'subsample': 0.682096039905861, 'colsample_bytree': 0.4744414312522798, 'colsample_bylevel': 0.6012956240696284, 'colsample_bynode': 0.8657776759987144, 'gamma': 4.565967806844698, 'reg_alpha': 19.615039406475297, 'reg_lambda': 42.03048404165418}. Best is trial 27 with value: 0.0964185050225329.
# [I 2025-07-25 16:30:21,528] Trial 37 finished with value: 0.09805377373438989 and parameters: {'learning_rate': 0.02912452717708021, 'max_depth': 7, 'max_leaves': 27, 'min_child_weight': 17, 'subsample': 0.5946771883507798, 'colsample_bytree': 0.874195975595038, 'colsample_bylevel': 0.4853232775683589, 'colsample_bynode': 0.4548743462397835, 'gamma': 3.3012182902440736, 'reg_alpha': 15.129445430195695, 'reg_lambda': 7.937061661813733}. Best is trial 37 with value: 0.09805377373438989.
# [I 2025-07-25 16:30:25,782] Trial 38 finished with value: 0.07221840761086595 and parameters: {'learning_rate': 0.03142496471595923, 'max_depth': 7, 'max_leaves': 31, 'min_child_weight': 19, 'subsample': 0.5817876871272121, 'colsample_bytree': 0.8886893005808016, 'colsample_bylevel': 0.49826224072998127, 'colsample_bynode': 0.36518061909786304, 'gamma': 3.7093529593141787, 'reg_alpha': 14.258339595819548, 'reg_lambda': 18.649302698718927}. Best is trial 37 with value: 0.09805377373438989.
# [I 2025-07-25 16:30:29,688] Trial 39 finished with value: 0.0722675122545511 and parameters: {'learning_rate': 0.06411899505460446, 'max_depth': 4, 'max_leaves': 28, 'min_child_weight': 21, 'subsample': 0.6319837335240517, 'colsample_bytree': 0.7928222985287325, 'colsample_bylevel': 0.3589619374093773, 'colsample_bynode': 0.445716578994887, 'gamma': 3.236454249478991, 'reg_alpha': 9.629334275060408, 'reg_lambda': 55.2911906855552}. Best is trial 37 with value: 0.09805377373438989.
# [I 2025-07-25 16:30:33,967] Trial 40 finished with value: 0.06580490444602662 and parameters: {'learning_rate': 0.0264136232635302, 'max_depth': 10, 'max_leaves': 39, 'min_child_weight': 17, 'subsample': 0.4632239417618683, 'colsample_bytree': 0.8835909015788609, 'colsample_bylevel': 0.7860749985908332, 'colsample_bynode': 0.4874749286388231, 'gamma': 2.800178368737892, 'reg_alpha': 5.445572093604923, 'reg_lambda': 29.774992176762925}. Best is trial 37 with value: 0.09805377373438989.
# [I 2025-07-25 16:30:38,265] Trial 41 finished with value: 0.06499833460758386 and parameters: {'learning_rate': 0.021661830073538297, 'max_depth': 7, 'max_leaves': 21, 'min_child_weight': 9, 'subsample': 0.63246912876574, 'colsample_bytree': 0.6052809037622601, 'colsample_bylevel': 0.5554926254722635, 'colsample_bynode': 0.48491519955675755, 'gamma': 3.8625002652506586, 'reg_alpha': 15.860705641142701, 'reg_lambda': 10.054164500210085}. Best is trial 37 with value: 0.09805377373438989.
# [I 2025-07-25 16:30:42,967] Trial 42 finished with value: 0.08719145663711485 and parameters: {'learning_rate': 0.015035231011303362, 'max_depth': 12, 'max_leaves': 15, 'min_child_weight': 19, 'subsample': 0.8498471391341454, 'colsample_bytree': 0.7562312472085723, 'colsample_bylevel': 0.6538991854015592, 'colsample_bynode': 0.5516744784747963, 'gamma': 3.3105120456489527, 'reg_alpha': 22.849771291731184, 'reg_lambda': 2.9458195905059386}. Best is trial 37 with value: 0.09805377373438989.
# [I 2025-07-25 16:30:47,118] Trial 43 finished with value: 0.09850463858365326 and parameters: {'learning_rate': 0.05099576249497926, 'max_depth': 9, 'max_leaves': 10, 'min_child_weight': 29, 'subsample': 0.7788747847846023, 'colsample_bytree': 0.9313943903768038, 'colsample_bylevel': 0.7176997452903963, 'colsample_bynode': 0.3841562563047245, 'gamma': 4.38050016772387, 'reg_alpha': 13.641734845983727, 'reg_lambda': 6.23533869909871}. Best is trial 43 with value: 0.09850463858365326.
# [I 2025-07-25 16:30:51,119] Trial 44 finished with value: 0.07267525733357325 and parameters: {'learning_rate': 0.048850257659904646, 'max_depth': 9, 'max_leaves': 27, 'min_child_weight': 30, 'subsample': 0.7022956242889564, 'colsample_bytree': 0.9370423701490251, 'colsample_bylevel': 0.7326556205132779, 'colsample_bynode': 0.394286870024403, 'gamma': 4.263962876104987, 'reg_alpha': 12.565491737899377, 'reg_lambda': 14.77757757422965}. Best is trial 43 with value: 0.09850463858365326.
# [I 2025-07-25 16:30:55,054] Trial 45 finished with value: 0.07763365100671211 and parameters: {'learning_rate': 0.06767665063209785, 'max_depth': 8, 'max_leaves': 9, 'min_child_weight': 25, 'subsample': 0.5706518193766694, 'colsample_bytree': 0.8631766546807975, 'colsample_bylevel': 0.7664737267527443, 'colsample_bynode': 0.31162209379078154, 'gamma': 4.960101959987666, 'reg_alpha': 20.478195211649762, 'reg_lambda': 6.840527347882685}. Best is trial 43 with value: 0.09850463858365326.
# [I 2025-07-25 16:30:59,115] Trial 46 finished with value: 0.0736066628020493 and parameters: {'learning_rate': 0.03848752219637451, 'max_depth': 11, 'max_leaves': 19, 'min_child_weight': 27, 'subsample': 0.5367774210311866, 'colsample_bytree': 0.9726507771352075, 'colsample_bylevel': 0.8305297816288115, 'colsample_bynode': 0.4317432816776444, 'gamma': 4.682052374850688, 'reg_alpha': 14.473107997620735, 'reg_lambda': 68.39380843629752}. Best is trial 43 with value: 0.09850463858365326.
# [I 2025-07-25 16:31:02,985] Trial 47 finished with value: 0.07042440724041908 and parameters: {'learning_rate': 0.11827858474426614, 'max_depth': 7, 'max_leaves': 11, 'min_child_weight': 24, 'subsample': 0.7306600399043899, 'colsample_bytree': 0.9254086947475268, 'colsample_bylevel': 0.6123248519258877, 'colsample_bynode': 0.3666788863279378, 'gamma': 3.6794065174842783, 'reg_alpha': 18.43856254982441, 'reg_lambda': 10.829285097640131}. Best is trial 43 with value: 0.09850463858365326.
# [I 2025-07-25 16:31:07,122] Trial 48 finished with value: 0.0891565982681939 and parameters: {'learning_rate': 0.05030400214714696, 'max_depth': 9, 'max_leaves': 26, 'min_child_weight': 28, 'subsample': 0.6496732175090484, 'colsample_bytree': 0.7963888774618609, 'colsample_bylevel': 0.4705321041284696, 'colsample_bynode': 0.4617404686706281, 'gamma': 4.3680532455092, 'reg_alpha': 9.260114903035749, 'reg_lambda': 16.65447534047989}. Best is trial 43 with value: 0.09850463858365326.
# [I 2025-07-25 16:31:10,993] Trial 49 finished with value: 0.11735128353020946 and parameters: {'learning_rate': 0.09258057678967159, 'max_depth': 3, 'max_leaves': 34, 'min_child_weight': 22, 'subsample': 0.5979983554389867, 'colsample_bytree': 0.9451406846342363, 'colsample_bylevel': 0.7268190491493042, 'colsample_bynode': 0.3357242329928344, 'gamma': 2.3660829037739393, 'reg_alpha': 16.635256680506135, 'reg_lambda': 5.266093237811045}. Best is trial 49 with value: 0.11735128353020946.
# Best Pearson correlation: 0.11735128353020946
# Best Parameters: {'learning_rate': 0.09258057678967159, 'max_depth': 3, 'max_leaves': 34, 'min_child_weight': 22, 'subsample': 0.5979983554389867, 'colsample_bytree': 0.9451406846342363, 'colsample_bylevel': 0.7268190491493042, 'colsample_bynode': 0.3357242329928344, 'gamma': 2.3660829037739393, 'reg_alpha': 16.635256680506135, 'reg_lambda': 5.266093237811045}

# %%
best_params = study.best_params

# Add required non-tuned params
best_params.update({
    "tree_method": "hist",
    "device": "cuda",
    "random_state": 42,
    "n_jobs": -1,
    "early_stopping_rounds": 50,
    "eval_metric": "rmse"
})

final_model = xgb.XGBRegressor(**best_params)
final_model.fit(
    X_train,
    y_train,
    eval_set=[(X_valid, y_valid)],
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=0.7268190491493042,
#              colsample_bynode=0.3357242329928344,
#              colsample_bytree=0.9451406846342363, device='cuda',
#              early_stopping_rounds=50, enable_categorical=False,
#              eval_metric='rmse', feature_types=None, gamma=2.3660829037739393,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.09258057678967159,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=34,
#              min_child_weight=22, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=-1,
#              num_parallel_tree=None, random_state=42, ...)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_y = MinMaxScaler()
scaler_y.fit(y_train.values.reshape(-1, 1))
# Out:
# MinMaxScaler()

# %%
y_train
# Out:
# 2023-03-01 00:00:00    0.562539
# 2023-03-01 00:01:00    0.533686
# 2023-03-01 00:02:00    0.546505
# 2023-03-01 00:03:00    0.357703
# 2023-03-01 00:04:00    0.362452
#                          ...
# 2023-11-30 11:41:00    0.370834
# 2023-11-30 11:42:00    0.279049
# 2023-11-30 11:43:00    0.280720
# 2023-11-30 11:44:00    0.321828
# 2023-11-30 11:45:00    0.273688
# Name: label, Length: 394415, dtype: float64

# %%
preds = final_model.predict(X_test)

# %%
scaled_predictions = scaler_y.fit(preds.reshape(-1, 1))
preds
# Out:
# array([ 0.0246935 ,  0.01550626,  0.01550626, ...,  0.01550626,
#        -0.00460351,  0.0246935 ], dtype=float32)

# %%
submission_df = pd.read_csv("/kaggle/input/drw-crypto-market-prediction/sample_submission.csv")
if 'label' in submission_df.columns:
    submission_df = submission_df.drop(columns=['label'])
submission_df["prediction"] = preds
submission_df.to_csv("submission.csv", index=False)
    
print("\nSubmission file 'submission.csv' created successfully.")
print(submission_df.head())
# Out:
# Submission file 'submission.csv' created successfully.
#    ID  prediction
# 0   1    0.024694
# 1   2    0.015506
# 2   3    0.015506
# 3   4   -0.006885
# 4   5    0.015506
